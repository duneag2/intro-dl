# %%
# Colab : Connecting Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#linux
# !pwd
# Out:
# /content

# %%
# !ls -l # list of files that are stored in the current directory
# Out:
# total 8
# drwx------ 5 root root 4096 Mar 30 08:17 drive
# drwxr-xr-x 1 root root 4096 Mar 28 23:00 sample_data

# %%
# %cd /content/drive/MyDrive/제목없는 폴더
# Out:
# /content/drive/MyDrive/제목없는 폴더

# %%
# Use GPU
# !nvidia-smi

# Activate your GPU
## Refer to this link:
## https://wscode.tistory.com/30
## OR 런타임 - 런타임 유형 변경 - T4, GPU
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
# !ls -1
# Out:
# afhq

# %%
# %cd afhq
# Out:
# /content/drive/MyDrive/제목없는 폴더/afhq

# %%
# os

import os

os.getcwd()
# Out:
# '/content/drive/MyDrive/제목없는 폴더'

# %%
os.chdir('/content/drive/MyDrive/제목없는 폴더')

# %%
os.mkdir('temp') # make directory

# %%
os.listdir(os.getcwd()) # file/folder list
# Out:
# ['afhq', '.ipynb_checkpoints', 'temp']

# %%
len(os.listdir(os.getcwd())) # files or folders 개수
# Out:
# 3

# %%
# Question 1. How can I move to the directory I want using the library os & Linux Command?
# I'd like to move to the directory name '/content/sample_data'.

# %%
os.chdir('/content/sample_data')

# %%
os.getcwd()
# Out:
# '/content/sample_data'

# %%
# cd
# %cd /content/sample_data
# Out:
# /content/drive/MyDrive/제목없는 폴더/afhq

# %%
# shutil
import shutil

os.chdir('/content/drive/MyDrive/제목없는 폴더/afhq')

# %%
# !ls -l #파일 내역, 생성 날짜
# Out:
# total 0

# %%
f = open("new.txt", 'w') # make a txt file name new
f.close()

# %%
# !ls -l
# Out:
# total 0
# -rw------- 1 root root 0 Mar 30 08:27 new.txt

# %%
# !mkdir new_folder

# %%
# !ls -1
# Out:
# new_folder

# %%
src = '/content/drive/MyDrive/제목없는 폴더/afhq/new.txt' # source directory -- python convention
dst = '/content/drive/MyDrive/제목없는 폴더/afhq/new_folder/new.txt' # destination directory -- python convention

# %%
shutil.move(src, dst)
# Out:
# '/content/drive/MyDrive/제목없는 폴더/afhq/new_folder/new.txt'

# %%
# %cd /content/drive/MyDrive/제목없는 폴더/afhq/new_folder
# Out:
# /content/drive/MyDrive/제목없는 폴더/afhq/new_folder

# %%
# !ls -l
# Out:
# total 0
# -rw------- 1 root root 0 Mar 30 08:27 new.txt

# %%
src2 = '/content/drive/MyDrive/제목없는 폴더/afhq/new_folder/new.txt' # source directory -- python convention
dst2 = '/content/drive/MyDrive/제목없는 폴더/afhq/new_folder/new2.txt' # destination directory -- python convention

# %%
shutil.copy(src2, dst2)
# Out:
# '/content/drive/MyDrive/제목없는 폴더/afhq/new_folder/new2.txt'

# %%
# !ls -l
# Out:
# total 0
# -rw------- 1 root root 0 Mar 30 08:33 new2.txt
# -rw------- 1 root root 0 Mar 30 08:27 new.txt

# %%
#Question 2. Please write a code that copies new.txt with a file name new3.txt.

src3 = '/content/drive/MyDrive/제목없는 폴더/afhq/new_folder/new.txt'
dst3 = '/content/drive/MyDrive/제목없는 폴더/afhq/new_folder/new3.txt'

# %%
shutil.copy(src3, dst3)
# Out:
# '/content/drive/MyDrive/제목없는 폴더/afhq/new_folder/new3.txt'

# %%
# %cd '/content/drive/MyDrive/제목없는 폴더/afhq/new_folder'
# Out:
# /content/drive/MyDrive/제목없는 폴더/afhq/new_folder

# %%
# !ls -1
# Out:
# new2.txt
# new3.txt
# new.txt

# %%
# Basic Pytorch

import torch

# %%
# Representing Scalars w/ Pytorch (2 ways)

# %%
scalar1 = torch.tensor([1.])
print(scalar1)
# Out:
# tensor([1.])

# %%
scalar2 = torch.tensor([3.])
print(scalar2)
# Out:
# tensor([3.])

# %%
add_scalar = scalar1 + scalar2 # addition
print(add_scalar)
# Out:
# tensor([4.])

# %%
sub_scalar = scalar1 - scalar2 # subtraction
print(sub_scalar)
# Out:
# tensor([-2.])

# %%
mul_scalar = scalar1 * scalar2 # multiplication
print(mul_scalar)
# Out:
# tensor([3.])

# %%
div_scalar = scalar1 / scalar2 # division
print(div_scalar)
# Out:
# tensor([0.3333])

# %%
torch.add(scalar1, scalar2) # addition
# Out:
# tensor([4.])

# %%
torch.sub(scalar1, scalar2) # division
# Out:
# tensor([-2.])

# %%
torch.mul(scalar1, scalar2) # multiplication
# Out:
# tensor([3.])

# %%
torch.div(scalar1, scalar2) # division
# Out:
# tensor([0.3333])

# %%
# Representing Vectors w/ Pytorch (2 ways)

# %%
vector1 = torch.tensor([1., 2., 3.])
print(vector1)
# Out:
# tensor([1., 2., 3.])

# %%
vector2 = torch.tensor([4., 5., 6.])
print(vector2)
# Out:
# tensor([4., 5., 6.])

# %%
add_vector = vector1 + vector2 # addition
print(add_vector)
# Out:
# tensor([5., 7., 9.])

# %%
sub_vector = vector1 - vector2 # subtraction
print(sub_vector)
# Out:
# tensor([-3., -3., -3.])

# %%
mul_vector = vector1 * vector2
print(mul_vector)
# Out:
# tensor([ 4., 10., 18.])

# %%
div_vector = vector1 / vector2
print(div_vector)
# Out:
# tensor([0.2500, 0.4000, 0.5000])

# %%
torch.add(vector1,vector2)
# Out:
# tensor([5., 7., 9.])

# %%
torch.sub(vector1,vector2)
# Out:
# tensor([-3., -3., -3.])

# %%
torch.mul(vector1,vector2)
# Out:
# tensor([ 4., 10., 18.])

# %%
torch.div(vector1,vector2)
# Out:
# tensor([0.2500, 0.4000, 0.5000])

# %%
torch.dot(vector1,vector2)
# Out:
# tensor(32.)

# %%
# Representing Matrices w/ Pytorch (2 ways)

# %%
# matrix1, matrix2
matrix1 = torch.tensor([[1., 2.], [3., 4.]])
print(matrix1)
# Out:
# tensor([[1., 2.],
#         [3., 4.]])

# %%
matrix2 = torch.tensor([[5., 6.], [7., 8.]])
print(matrix2)
# Out:
# tensor([[5., 6.],
#         [7., 8.]])

# %%
sum_matrix = matrix1 + matrix2
print(sum_matrix)
# Out:
# tensor([[ 6.,  8.],
#         [10., 12.]])

# %%
sub_matrix = matrix1 - matrix2
print(sub_matrix)
# Out:
# tensor([[-4., -4.],
#         [-4., -4.]])

# %%
mul_matrix = matrix1 * matrix2
print(mul_matrix)
# Out:
# tensor([[ 5., 12.],
#         [21., 32.]])

# %%
div_matrix = matrix1 / matrix2
print(div_matrix)
# Out:
# tensor([[0.2000, 0.3333],
#         [0.4286, 0.5000]])

# %%
torch.add(matrix1,matrix2)
# Out:
# tensor([[ 6.,  8.],
#         [10., 12.]])

# %%
torch.sub(matrix1,matrix2)
# Out:
# tensor([[-4., -4.],
#         [-4., -4.]])

# %%
torch.mul(matrix1,matrix2)
# Out:
# tensor([[ 5., 12.],
#         [21., 32.]])

# %%
torch.div(matrix1,matrix2)
# Out:
# tensor([[0.2000, 0.3333],
#         [0.4286, 0.5000]])

# %%
torch.matmul(matrix1,matrix2)
# Out:
# tensor([[19., 22.],
#         [43., 50.]])

# %%
# Question 3. Compute L1/L2 Norm between matrix1 and matrix2 above.

norm1 = torch.linalg.matrix_norm(matrix1-matrix2, ord=1)

# %%
norm2 = torch.linalg.matrix_norm(matrix1-matrix2, ord=2)

# %%
## Hard Mode (Optional)
## Compute Cosine Similarity between matrix1 and matrix2 above.

cosine_similarity = torch.matmul(matrix1,matrix2) / (norm1 * norm2)
print(cosine_similarity)
# Out:
# tensor([[0.2969, 0.3437],
#         [0.6719, 0.7812]])

# %%
# Simple MLP

import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms, datasets

# %%
if torch.cuda.is_available():
    DEVICE = torch.device('cuda')
else:
    DEVICE = torch.device('cpu')

print('Using PyTorch version:', torch.__version__, ' Device:', DEVICE)
# Out:
# Using PyTorch version: 2.2.1+cu121  Device: cpu

# %%
BATCH_SIZE = 32
EPOCHS = 10

# %%
''' 3. MNIST Download (Train set, Test set split) '''
train_dataset = datasets.MNIST(root = "../data/MNIST",
                               train = True,
                               download = True,
                               transform = transforms.ToTensor())

test_dataset = datasets.MNIST(root = "../data/MNIST",
                              train = False,
                              transform = transforms.ToTensor())

train_loader = torch.utils.data.DataLoader(dataset = train_dataset,
                                           batch_size = BATCH_SIZE,
                                           shuffle = True)

test_loader = torch.utils.data.DataLoader(dataset = test_dataset,
                                          batch_size = BATCH_SIZE,
                                          shuffle = False)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ../data/MNIST/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 101604657.10it/s]
# Extracting ../data/MNIST/MNIST/raw/train-images-idx3-ubyte.gz to ../data/MNIST/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ../data/MNIST/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 32038004.19it/s]
# Extracting ../data/MNIST/MNIST/raw/train-labels-idx1-ubyte.gz to ../data/MNIST/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ../data/MNIST/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 29143716.67it/s]
# Extracting ../data/MNIST/MNIST/raw/t10k-images-idx3-ubyte.gz to ../data/MNIST/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ../data/MNIST/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 17606773.35it/s]
# Extracting ../data/MNIST/MNIST/raw/t10k-labels-idx1-ubyte.gz to ../data/MNIST/MNIST/raw

# %%
for (X_train, y_train) in train_loader:
    print('X_train:', X_train.size(), 'type:', X_train.type())
    print('y_train:', y_train.size(), 'type:', y_train.type())
    break
# Out:
# X_train: torch.Size([32, 1, 28, 28]) type: torch.FloatTensor
# y_train: torch.Size([32]) type: torch.LongTensor

# %%
pltsize = 1
plt.figure(figsize=(10 * pltsize, pltsize))
for i in range(10):
    plt.subplot(1, 10, i + 1)
    plt.axis('off')
    plt.imshow(X_train[i, :, :, :].numpy().reshape(28, 28), cmap = "gray_r")
    plt.title('Class: ' + str(y_train[i].item()))

# %%
''' Multi Layer Perceptron '''
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(28 * 28, 512)
        self.fc2 = nn.Linear(512, 256)
        self.fc3 = nn.Linear(256, 10)

    def forward(self, x):
        x = x.view(-1, 28 * 28)
        x = self.fc1(x)
        x = F.sigmoid(x)
        x = self.fc2(x)
        x = F.sigmoid(x)
        x = self.fc3(x)
        x = F.log_softmax(x, dim = 1)
        return x

# %%
''' Optimizer, Objective Function '''
model = Net().to(DEVICE)
optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum = 0.5)
criterion = nn.CrossEntropyLoss()

print(model)
# Out:
# Net(
#   (fc1): Linear(in_features=784, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=10, bias=True)
# )

# %%
def train(model, train_loader, optimizer, log_interval):
    model.train()
    for batch_idx, (image, label) in enumerate(train_loader):
        image = image.to(DEVICE)
        label = label.to(DEVICE)
        optimizer.zero_grad()
        output = model(image)
        loss = criterion(output, label)
        loss.backward()
        optimizer.step()

        if batch_idx % log_interval == 0:
            print("Train Epoch: {} [{}/{} ({:.0f}%)]\tTrain Loss: {:.6f}".format(
                epoch, batch_idx * len(image),
                len(train_loader.dataset), 100. * batch_idx / len(train_loader),
                loss.item()))

# %%
def evaluate(model, test_loader):
    model.eval()
    test_loss = 0
    correct = 0

    with torch.no_grad():
        for image, label in test_loader:
            image = image.to(DEVICE)
            label = label.to(DEVICE)
            output = model(image)
            test_loss += criterion(output, label).item()
            prediction = output.max(1, keepdim = True)[1]
            correct += prediction.eq(label.view_as(prediction)).sum().item()

    test_loss /= (len(test_loader.dataset) / BATCH_SIZE)
    test_accuracy = 100. * correct / len(test_loader.dataset)
    return test_loss, test_accuracy

# %%
for epoch in range(1, EPOCHS + 1):
    train(model, train_loader, optimizer, log_interval = 200)
    test_loss, test_accuracy = evaluate(model, test_loader)
    print("\n[EPOCH: {}], \tTest Loss: {:.4f}, \tTest Accuracy: {:.2f} % \n".format(
        epoch, test_loss, test_accuracy))
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Train Loss: 2.281750
# Train Epoch: 1 [6400/60000 (11%)]	Train Loss: 2.253399
# Train Epoch: 1 [12800/60000 (21%)]	Train Loss: 2.329169
# Train Epoch: 1 [19200/60000 (32%)]	Train Loss: 2.334622
# Train Epoch: 1 [25600/60000 (43%)]	Train Loss: 2.314021
# Train Epoch: 1 [32000/60000 (53%)]	Train Loss: 2.290249
# Train Epoch: 1 [38400/60000 (64%)]	Train Loss: 2.315418
# Train Epoch: 1 [44800/60000 (75%)]	Train Loss: 2.293669
# Train Epoch: 1 [51200/60000 (85%)]	Train Loss: 2.257475
# Train Epoch: 1 [57600/60000 (96%)]	Train Loss: 2.218565
#
# [EPOCH: 1], 	Test Loss: 2.2348, 	Test Accuracy: 24.06 %
#
# Train Epoch: 2 [0/60000 (0%)]	Train Loss: 2.241399
# Train Epoch: 2 [6400/60000 (11%)]	Train Loss: 2.202079
# Train Epoch: 2 [12800/60000 (21%)]	Train Loss: 2.143046
# Train Epoch: 2 [19200/60000 (32%)]	Train Loss: 2.120377
# Train Epoch: 2 [25600/60000 (43%)]	Train Loss: 1.964294
# Train Epoch: 2 [32000/60000 (53%)]	Train Loss: 1.888989
# Train Epoch: 2 [38400/60000 (64%)]	Train Loss: 1.641656
# Train Epoch: 2 [44800/60000 (75%)]	Train Loss: 1.377080
# Train Epoch: 2 [51200/60000 (85%)]	Train Loss: 1.367268
# Train Epoch: 2 [57600/60000 (96%)]	Train Loss: 1.344927
#
# [EPOCH: 2], 	Test Loss: 1.2904, 	Test Accuracy: 61.95 %
#
# Train Epoch: 3 [0/60000 (0%)]	Train Loss: 1.454512
# Train Epoch: 3 [6400/60000 (11%)]	Train Loss: 1.154430
# Train Epoch: 3 [12800/60000 (21%)]	Train Loss: 1.236592
# Train Epoch: 3 [19200/60000 (32%)]	Train Loss: 0.856273
# Train Epoch: 3 [25600/60000 (43%)]	Train Loss: 1.152926
# Train Epoch: 3 [32000/60000 (53%)]	Train Loss: 0.659410
# Train Epoch: 3 [38400/60000 (64%)]	Train Loss: 0.790269
# Train Epoch: 3 [44800/60000 (75%)]	Train Loss: 0.946589
# Train Epoch: 3 [51200/60000 (85%)]	Train Loss: 0.942681
# Train Epoch: 3 [57600/60000 (96%)]	Train Loss: 0.585808
#
# [EPOCH: 3], 	Test Loss: 0.7392, 	Test Accuracy: 77.94 %
#
# Train Epoch: 4 [0/60000 (0%)]	Train Loss: 0.656366
# Train Epoch: 4 [6400/60000 (11%)]	Train Loss: 0.621883
# Train Epoch: 4 [12800/60000 (21%)]	Train Loss: 0.613849
# Train Epoch: 4 [19200/60000 (32%)]	Train Loss: 0.644189
# Train Epoch: 4 [25600/60000 (43%)]	Train Loss: 0.963180
# Train Epoch: 4 [32000/60000 (53%)]	Train Loss: 0.740245
# Train Epoch: 4 [38400/60000 (64%)]	Train Loss: 0.601815
# Train Epoch: 4 [44800/60000 (75%)]	Train Loss: 0.580497
# Train Epoch: 4 [51200/60000 (85%)]	Train Loss: 0.425003
# Train Epoch: 4 [57600/60000 (96%)]	Train Loss: 0.870479
#
# [EPOCH: 4], 	Test Loss: 0.5535, 	Test Accuracy: 83.71 %
#
# Train Epoch: 5 [0/60000 (0%)]	Train Loss: 0.308782
# Train Epoch: 5 [6400/60000 (11%)]	Train Loss: 0.586054
# Train Epoch: 5 [12800/60000 (21%)]	Train Loss: 0.656363
# Train Epoch: 5 [19200/60000 (32%)]	Train Loss: 0.568983
# Train Epoch: 5 [25600/60000 (43%)]	Train Loss: 0.532792
# Train Epoch: 5 [32000/60000 (53%)]	Train Loss: 0.506130
# Train Epoch: 5 [38400/60000 (64%)]	Train Loss: 0.457731
# Train Epoch: 5 [44800/60000 (75%)]	Train Loss: 0.527925
# Train Epoch: 5 [51200/60000 (85%)]	Train Loss: 0.505004
# Train Epoch: 5 [57600/60000 (96%)]	Train Loss: 0.671944
#
# [EPOCH: 5], 	Test Loss: 0.4622, 	Test Accuracy: 86.45 %
#
# Train Epoch: 6 [0/60000 (0%)]	Train Loss: 0.354117
# Train Epoch: 6 [6400/60000 (11%)]	Train Loss: 0.414007
# Train Epoch: 6 [12800/60000 (21%)]	Train Loss: 0.901640
# Train Epoch: 6 [19200/60000 (32%)]	Train Loss: 0.358404
# Train Epoch: 6 [25600/60000 (43%)]	Train Loss: 0.509516
# Train Epoch: 6 [32000/60000 (53%)]	Train Loss: 0.307603
# Train Epoch: 6 [38400/60000 (64%)]	Train Loss: 0.488699
# Train Epoch: 6 [44800/60000 (75%)]	Train Loss: 0.276572
# Train Epoch: 6 [51200/60000 (85%)]	Train Loss: 0.345766
# Train Epoch: 6 [57600/60000 (96%)]	Train Loss: 0.477509
#
# [EPOCH: 6], 	Test Loss: 0.4170, 	Test Accuracy: 87.72 %
#
# Train Epoch: 7 [0/60000 (0%)]	Train Loss: 0.495636
# Train Epoch: 7 [6400/60000 (11%)]	Train Loss: 0.875716
# Train Epoch: 7 [12800/60000 (21%)]	Train Loss: 0.234224
# Train Epoch: 7 [19200/60000 (32%)]	Train Loss: 0.432594
# Train Epoch: 7 [25600/60000 (43%)]	Train Loss: 0.305291
# Train Epoch: 7 [32000/60000 (53%)]	Train Loss: 0.460966
# Train Epoch: 7 [38400/60000 (64%)]	Train Loss: 0.326620
# Train Epoch: 7 [44800/60000 (75%)]	Train Loss: 0.253049
# Train Epoch: 7 [51200/60000 (85%)]	Train Loss: 0.230273
# Train Epoch: 7 [57600/60000 (96%)]	Train Loss: 0.238098
#
# [EPOCH: 7], 	Test Loss: 0.3834, 	Test Accuracy: 88.76 %
#
# Train Epoch: 8 [0/60000 (0%)]	Train Loss: 0.250698
# Train Epoch: 8 [6400/60000 (11%)]	Train Loss: 0.355135
# Train Epoch: 8 [12800/60000 (21%)]	Train Loss: 0.362760
# Train Epoch: 8 [19200/60000 (32%)]	Train Loss: 0.521079
# Train Epoch: 8 [25600/60000 (43%)]	Train Loss: 0.444174
# Train Epoch: 8 [32000/60000 (53%)]	Train Loss: 0.400731
# Train Epoch: 8 [38400/60000 (64%)]	Train Loss: 0.291681
# Train Epoch: 8 [44800/60000 (75%)]	Train Loss: 0.284536
# Train Epoch: 8 [51200/60000 (85%)]	Train Loss: 0.225644
# Train Epoch: 8 [57600/60000 (96%)]	Train Loss: 0.387116
#
# [EPOCH: 8], 	Test Loss: 0.3616, 	Test Accuracy: 89.54 %
#
# Train Epoch: 9 [0/60000 (0%)]	Train Loss: 0.255044
# Train Epoch: 9 [6400/60000 (11%)]	Train Loss: 0.213083
# Train Epoch: 9 [12800/60000 (21%)]	Train Loss: 0.348704
# Train Epoch: 9 [19200/60000 (32%)]	Train Loss: 0.248271
# Train Epoch: 9 [25600/60000 (43%)]	Train Loss: 0.212065
# Train Epoch: 9 [32000/60000 (53%)]	Train Loss: 0.309505
# Train Epoch: 9 [38400/60000 (64%)]	Train Loss: 0.145520
# Train Epoch: 9 [44800/60000 (75%)]	Train Loss: 0.228285
# Train Epoch: 9 [51200/60000 (85%)]	Train Loss: 0.201364
# Train Epoch: 9 [57600/60000 (96%)]	Train Loss: 0.160040
#
# [EPOCH: 9], 	Test Loss: 0.3436, 	Test Accuracy: 90.08 %
#
# Train Epoch: 10 [0/60000 (0%)]	Train Loss: 0.270896
# Train Epoch: 10 [6400/60000 (11%)]	Train Loss: 0.412550
# Train Epoch: 10 [12800/60000 (21%)]	Train Loss: 0.478004
# Train Epoch: 10 [19200/60000 (32%)]	Train Loss: 0.247471
# Train Epoch: 10 [25600/60000 (43%)]	Train Loss: 0.494578
# Train Epoch: 10 [32000/60000 (53%)]	Train Loss: 0.456955
# Train Epoch: 10 [38400/60000 (64%)]	Train Loss: 0.242907
# Train Epoch: 10 [44800/60000 (75%)]	Train Loss: 0.396931
# Train Epoch: 10 [51200/60000 (85%)]	Train Loss: 0.413928
# Train Epoch: 10 [57600/60000 (96%)]	Train Loss: 0.691512
#
# [EPOCH: 10], 	Test Loss: 0.3329, 	Test Accuracy: 90.37 %

# %%
# Question 4. Please write a line-by-line explanation of the code above. (Simple MLP only)

# %%
#Question 5 (Optional). Please read and summarize the following 3 documents:
