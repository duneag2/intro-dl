# %% [markdown]
# # 2024 Winter Introduction to Deep Learning
# ### Based on Prof. Oh's Youtube Lecture
# https://youtube.com/playlist?list=PLvbUC2Zh5oJvByu9KL82bswYT2IKf0K1M
#
# > Assignment #1
#
#
# *   Youtube Lecture #1-3
# *   Written by Seungeun Lee

# %% [markdown]
# ### Notice for Python
# ##### If you are new to Python, please follow the Youtube link below:
# ##### https://youtube.com/playlist?list=PLGPF8gvWLYyrkF85itdBHaOLSVbtdzBww
# ##### You really don't have to understand everything in this video!! Just get a feel for Python:)
# ##### If you have any trouble installing Python3, just use online python compiler -- I recommend https://www.programiz.com/python-programming/online-compiler/

# %% [markdown]
# ## How to use Google Colaboratory

# %% [markdown]
# ##### First, please download a zip file from https://www.kaggle.com/datasets/andrewmvd/animal-faces
# ##### Activate you Colaboratory and upload your zip file -- please follow the links below:
#
# *   https://yeko90.tistory.com/entry/how-use-google-colab
# *   https://yeko90.tistory.com/entry/%ED%8C%8C%EC%9D%B4%EC%8D%AC-colab%EC%BD%94%EB%9E%A9%EC%97%90%EC%84%9C-%EC%95%95%EC%B6%95%ED%8C%8C%EC%9D%BC-%ED%92%80%EA%B8%B0

# %%
# connecting Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## How to Linux (Basic commands of Linux)
# ### Almost every Deep Learning Research is conducted based on Linux, including Colab.

# %%
# !pwd # current position
# Out:
# /content/sample_data

# %%
# !ls -l # list of files that are stored in the current directory
# Out:
# total 55504
# -rwxr-xr-x 1 root root     1697 Jan  1  2000 anscombe.json
# -rw-r--r-- 1 root root   301141 May 29 21:54 california_housing_test.csv
# -rw-r--r-- 1 root root  1706430 May 29 21:54 california_housing_train.csv
# -rw-r--r-- 1 root root 18289443 May 29 21:54 mnist_test.csv
# -rw-r--r-- 1 root root 36523880 May 29 21:54 mnist_train_small.csv
# -rwxr-xr-x 1 root root      930 Jan  1  2000 README.md

# %%
# 'c'hange 'd'irectory

# %%
# %cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# 'm'a'k'e 'dir'ectory
# !mkdir intro-dl

# %%
# %cd /content/drive/MyDrive/intro-dl
# Out:
# /content/drive/MyDrive/intro-dl

# %%
# !pwd
# Out:
# /content/drive/MyDrive/intro-dl

# %%
# !unzip -qq zip file name -d destination
# !unzip -qq /content/drive/MyDrive/intro-dl/archive.zip -d /content/drive/MyDrive/intro-dl

# %%
# !ls -l
# Out:
# total 712603
# drwx------ 4 root root      4096 May 31 04:55 afhq
# -rw------- 1 root root 729700755 May 31 04:28 archive.zip

# %%
# %cd afhq
# Out:
# /content/drive/MyDrive/intro-dl/afhq

# %%
# !ls -l
# Out:
# total 8
# drwx------ 5 root root 4096 May 31 04:54 train
# drwx------ 5 root root 4096 May 31 04:55 val

# %% [markdown]
# ## How to use GPU @ Google Colaboratory

# %%
# !nvidia-smi
# nothing will be shown (command not found)
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
# Activate your GPU
## Refer to this link:
## https://wscode.tistory.com/30
## OR 런타임 - 런타임 유형 변경 - T4 GPU

# %%
# !nvidia-smi # then the results will be shown
# Out:
# Fri May 31 04:58:12 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   55C    P8              11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# ## Basic Python Libraries

# %% [markdown]
# ### (1) os

# %%
import os # import package os

# %%
os.getcwd() # same as !pwd, current position -> but uses python library os
# Out:
# '/content'

# %%
os.chdir('/content/drive/MyDrive/intro-dl') # 'ch'ange 'dir'ectory

# %%
os.mkdir('temp') # 'm'a'k'e 'dir'ectory -> but uses python library os

# %%
os.listdir(os.getcwd()) # file/folder 'list' of the current 'dir'ectory -> but uses python library os
# Out:
# ['archive.zip', 'afhq', 'temp']

# %%
len(os.listdir(os.getcwd())) # # of files or folders of the current 'dir'ectory
# Out:
# 3

# %% [markdown]
# ### Question 1. How can I move to the directory I want using the library os & Linux Command?
#
#
# *   I'd like to move to the directory name '/content/sample_data'.

# %%
# Your Answer

# (1) os
os.chdir('/content/sample_data')

# %%
# (2) cd
# %cd /content/sample_data
# Out:
# /content

# %% [markdown]
# ### (2) shutil

# %%
import shutil

# %%
os.chdir('/content/drive/MyDrive/intro-dl/afhq')

# %%
# !ls -l
# Out:
# total 8
# drwx------ 5 root root 4096 May 31 04:51 train
# drwx------ 2 root root 4096 May 31 04:55 val

# %%
f = open("new.txt", 'w') # make a txt file name new
f.close()

# %%
# !ls -l
# Out:
# total 8
# -rw------- 1 root root    0 May 31 05:02 new.txt
# drwx------ 5 root root 4096 May 31 04:51 train
# drwx------ 2 root root 4096 May 31 04:55 val

# %%
# !mkdir new_folder

# %%
# !ls -l
# Out:
# total 12
# drwx------ 2 root root 4096 May 31 05:02 new_folder
# -rw------- 1 root root    0 May 31 05:02 new.txt
# drwx------ 5 root root 4096 May 31 04:51 train
# drwx------ 2 root root 4096 May 31 04:55 val

# %%
src = '/content/drive/MyDrive/intro-dl/afhq/new.txt' # source directory -- python convention
dst = '/content/drive/MyDrive/intro-dl/afhq/new_folder/new.txt' # destination directory -- python convention

# %%
shutil.move(src, dst) # from source to target -- move
# Out:
# '/content/drive/MyDrive/intro-dl/afhq/new_folder/new.txt'

# %%
# %cd /content/drive/MyDrive/intro-dl/afhq/new_folder
# Out:
# /content/drive/MyDrive/intro-dl/afhq/new_folder

# %%
# !ls -l
# Out:
# total 0
# -rw------- 1 root root 0 May 31 05:02 new.txt

# %%
src2 = '/content/drive/MyDrive/intro-dl/afhq/new_folder/new.txt' # source directory -- python convention
dst2 = '/content/drive/MyDrive/intro-dl/afhq/new_folder/new2.txt' # destination directory -- python convention

# %%
shutil.copy(src2, dst2) # from source to target -- copy
# Out:
# '/content/drive/MyDrive/intro-dl/afhq/new_folder/new2.txt'

# %%
# !ls -l
# Out:
# total 0
# -rw------- 1 root root 0 May 31 05:03 new2.txt
# -rw------- 1 root root 0 May 31 05:02 new.txt

# %% [markdown]
# ### Question 2. Please write a code that copies new.txt with a file name new3.txt.
# *   Directory: /content/drive/MyDrive/intro-dl/afhq/new_folder

# %%
# Your Answer

src3 = '/content/drive/MyDrive/intro-dl/afhq/new_folder/new.txt' # source directory
dst3 = '/content/drive/MyDrive/intro-dl/afhq/new_folder/new3.txt' # destination directory
shutil.copy(src3, dst3)
# Out:
# '/content/drive/MyDrive/intro-dl/afhq/new_folder/new3.txt'

# %%
## numpy, pandas -- later

# %% [markdown]
# ## Basic Pytorch
#
# *     Reference. https://github.com/Justin-A/DeepLearning101/blob/master/1-2_Basic_Autograd.ipynb

# %%
import torch

# %%
## Simple Question.
## What is (Py)torch?
## Google it and write the answer.

## Your Answer
"""
It is deep learning library for Python.
It helps calculation of tensors with GPU.
Also it provides more detailed DNN modification compared to Tensorflow.
"""

# %% [markdown]
# ### Representing Scalars w/ Pytorch (2 ways)

# %%
scalar1 = torch.tensor([1.])
print(scalar1)
# Out:
# tensor([1.])

# %%
scalar2 = torch.tensor([3.])
print(scalar2)
# Out:
# tensor([3.])

# %%
add_scalar = scalar1 + scalar2 # addition
print(add_scalar)
# Out:
# tensor([4.])

# %%
sub_scalar = scalar1 - scalar2 # subtraction
print(sub_scalar)
# Out:
# tensor([-2.])

# %%
mul_scalar = scalar1 * scalar2 # multiplication
print(mul_scalar)
# Out:
# tensor([3.])

# %%
div_scalar = scalar1 / scalar2 # division
print(div_scalar)
# Out:
# tensor([0.3333])

# %%
torch.add(scalar1, scalar2) # addition
# Out:
# tensor([4.])

# %%
torch.sub(scalar1, scalar2) # division
# Out:
# tensor([-2.])

# %%
torch.mul(scalar1, scalar2) # multiplication
# Out:
# tensor([3.])

# %%
torch.div(scalar1, scalar2) # division
# Out:
# tensor([0.3333])

# %% [markdown]
# ### Representing Vectors w/ Pytorch (2 ways)

# %%
vector1 = torch.tensor([1., 2., 3.])
print(vector1)
# Out:
# tensor([1., 2., 3.])

# %%
vector2 = torch.tensor([4., 5., 6.])
print(vector2)
# Out:
# tensor([4., 5., 6.])

# %%
add_vector = vector1 + vector2 # addition
print(add_vector)
# Out:
# tensor([5., 7., 9.])

# %%
sub_vector = vector1 - vector2 # subtraction
print(sub_vector)
# Out:
# tensor([-3., -3., -3.])

# %%
mul_vector = vector1 * vector2 # multiplication
print(mul_vector)
# Out:
# tensor([ 4., 10., 18.])

# %%
div_vector = vector1 / vector2 # division
print(div_vector)
# Out:
# tensor([0.2500, 0.4000, 0.5000])

# %%
torch.add(vector1, vector2) # addition
# Out:
# tensor([5., 7., 9.])

# %%
torch.sub(vector1, vector2) # subtraction
# Out:
# tensor([-3., -3., -3.])

# %%
torch.mul(vector1, vector2) # multiplication
# Out:
# tensor([ 4., 10., 18.])

# %%
torch.div(vector1, vector2) # division
# Out:
# tensor([0.2500, 0.4000, 0.5000])

# %%
torch.dot(vector1, vector2) # dot product
# Out:
# tensor(32.)

# %% [markdown]
# ### Representing Matrices w/ Pytorch (2 ways)

# %%
matrix1 = torch.tensor([[1., 2.], [3., 4.]])
print(matrix1)
# Out:
# tensor([[1., 2.],
#         [3., 4.]])

# %%
matrix2 = torch.tensor([[5., 6.], [7., 8.]])
print(matrix2)
# Out:
# tensor([[5., 6.],
#         [7., 8.]])

# %%
sum_matrix = matrix1 + matrix2 # element-wise addition
print(sum_matrix)
# Out:
# tensor([[ 6.,  8.],
#         [10., 12.]])

# %%
sub_matrix = matrix1 - matrix2 # element-wise subtraction
print(sub_matrix)
# Out:
# tensor([[-4., -4.],
#         [-4., -4.]])

# %%
mul_matrix = matrix1 * matrix2 # element-wise multiplication
print(mul_matrix)
# Out:
# tensor([[ 5., 12.],
#         [21., 32.]])

# %%
div_matrix = matrix1 / matrix2 # element-wise division
print(div_matrix)
# Out:
# tensor([[0.2000, 0.3333],
#         [0.4286, 0.5000]])

# %%
torch.add(matrix1, matrix2) # element-wise addition
# Out:
# tensor([[ 6.,  8.],
#         [10., 12.]])

# %%
torch.sub(matrix1, matrix2) # element-wise subtraction
# Out:
# tensor([[-4., -4.],
#         [-4., -4.]])

# %%
torch.mul(matrix1, matrix2) # element-wise multiplication
# Out:
# tensor([[ 5., 12.],
#         [21., 32.]])

# %%
torch.div(matrix1, matrix2) # element-wise division
# Out:
# tensor([[0.2000, 0.3333],
#         [0.4286, 0.5000]])

# %%
torch.matmul(matrix1, matrix2) # matrix multiplication
# Out:
# tensor([[19., 22.],
#         [43., 50.]])

# %% [markdown]
# ### Question 3. Compute L1/L2 Norm between matrix1 and matrix2 above.
# *     Hint: https://pytorch.org/docs/stable/generated/torch.linalg.norm.html

# %%
from typing import Tuple
## Your Answer

## L1 Norm
print(torch.norm(matrix1-matrix2, 1))
## L2 Norm
print(torch.norm(matrix1-matrix2, 2))
# Out:
# tensor(16.)
# tensor(8.)

# %%
## Hard Mode (Optional)
## Compute Cosine Similarity between matrix1 and matrix2 above.

## Your Answer
v1 = matrix1.flatten()
v2 = matrix2.flatten()
Nv = torch.dot(v1,v2) # Numerator
Dv = torch.norm(v1, 2) * torch.norm(v2, 2) # Denominator
print(Nv/Dv)
# Out:
# tensor(0.9689)

# %% [markdown]
# ## Simple MLP
#
# *    Reference. https://github.com/Justin-A/DeepLearning101/blob/master/2-1_MNIST_MLP.ipynb

# %%
''' 1. Module Import '''
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms, datasets

# %%
if torch.cuda.is_available():
    DEVICE = torch.device('cuda')
else:
    DEVICE = torch.device('cpu')

print('Using PyTorch version:', torch.__version__, ' Device:', DEVICE)
# Out:
# Using PyTorch version: 2.3.0+cu121  Device: cuda

# %%
BATCH_SIZE = 32
EPOCHS = 10

# Defining hyperparameters

# %%
''' 3. MNIST Download (Train set, Test set split) '''
train_dataset = datasets.MNIST(root = "../data/MNIST",
                               train = True,
                               download = True,
                               transform = transforms.ToTensor())

test_dataset = datasets.MNIST(root = "../data/MNIST",
                              train = False,
                              transform = transforms.ToTensor())

train_loader = torch.utils.data.DataLoader(dataset = train_dataset,
                                           batch_size = BATCH_SIZE,
                                           shuffle = True)

test_loader = torch.utils.data.DataLoader(dataset = test_dataset,
                                          batch_size = BATCH_SIZE,
                                          shuffle = False)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to ../data/MNIST/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 16284894.90it/s]
# Extracting ../data/MNIST/MNIST/raw/train-images-idx3-ubyte.gz to ../data/MNIST/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to ../data/MNIST/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 511637.03it/s]
# Extracting ../data/MNIST/MNIST/raw/train-labels-idx1-ubyte.gz to ../data/MNIST/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to ../data/MNIST/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 4417849.39it/s]
# Extracting ../data/MNIST/MNIST/raw/t10k-images-idx3-ubyte.gz to ../data/MNIST/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to ../data/MNIST/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 4370389.72it/s]
# Extracting ../data/MNIST/MNIST/raw/t10k-labels-idx1-ubyte.gz to ../data/MNIST/MNIST/raw

# %%
## Quick Question
# What is MNIST?
# Google it and write the answer
"""
It is database of handwritten digits.
It is used for practice of image processing AI.
"""

# %%
for (X_train, y_train) in train_loader:
    print('X_train:', X_train.size(), 'type:', X_train.type())
    print('y_train:', y_train.size(), 'type:', y_train.type())
    break

# X is input image with [Batch, Channel, Width, Height]
# Y is class with [Batch]
# Out:
# X_train: torch.Size([32, 1, 28, 28]) type: torch.FloatTensor
# y_train: torch.Size([32]) type: torch.LongTensor

# %%
pltsize = 1
plt.figure(figsize=(10 * pltsize, pltsize))
for i in range(10):
    plt.subplot(1, 10, i + 1)
    plt.axis('off')
    plt.imshow(X_train[i, :, :, :].numpy().reshape(28, 28), cmap = "gray_r")
    plt.title('Class: ' + str(y_train[i].item()))

# It shows 10 plots with for loop
# Also it hides axis
# It shows i-th image with 28x28 size and grayscale

# %%
''' Multi Layer Perceptron '''
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(28 * 28, 512)
        self.fc2 = nn.Linear(512, 256)
        self.fc3 = nn.Linear(256, 10)
    # Three FC layers are there
    # Number of features: 512 -> 256 -> 10
    # The last 10 means classification (0~9)

    def forward(self, x):
        x = x.view(-1, 28 * 28)
        x = self.fc1(x)
        x = F.sigmoid(x)
        x = self.fc2(x)
        x = F.sigmoid(x)
        x = self.fc3(x)
        x = F.log_softmax(x, dim = 1)
        return x
    # view(-1) means flattening image into vector
    # For 2 FC layers we take sigmoid as an activation
    # Last FC layer is classification so we use softmax

# %%
''' Optimizer, Objective Function '''
model = Net().to(DEVICE)
optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum = 0.5)
criterion = nn.CrossEntropyLoss()
# Learning rate 0.01
# Momentum 0.5 to avoid local minima
# Loss is cross entropy loss

print(model)
# Out:
# Net(
#   (fc1): Linear(in_features=784, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=10, bias=True)
# )

# %%
def train(model, train_loader, optimizer, log_interval):
    model.train()
    for batch_idx, (image, label) in enumerate(train_loader):
        image = image.to(DEVICE)
        label = label.to(DEVICE)
        optimizer.zero_grad()
        output = model(image)
        loss = criterion(output, label)
        loss.backward()
        optimizer.step()

        if batch_idx % log_interval == 0:
            print("Train Epoch: {} [{}/{} ({:.0f}%)]\tTrain Loss: {:.6f}".format(
                epoch, batch_idx * len(image),
                len(train_loader.dataset), 100. * batch_idx / len(train_loader),
                loss.item()))
        # For every 6400(=log_interval) data, we print log to see progress

# %%
def evaluate(model, test_loader):
    model.eval()
    test_loss = 0
    correct = 0

    with torch.no_grad():
        for image, label in test_loader:
            image = image.to(DEVICE)
            label = label.to(DEVICE)
            output = model(image)
            test_loss += criterion(output, label).item()
            prediction = output.max(1, keepdim = True)[1]
            correct += prediction.eq(label.view_as(prediction)).sum().item()
    # Calculate loss

    test_loss /= (len(test_loader.dataset) / BATCH_SIZE)
    test_accuracy = 100. * correct / len(test_loader.dataset)
    return test_loss, test_accuracy

# %%
for epoch in range(1, EPOCHS + 1):
    train(model, train_loader, optimizer, log_interval = 200)
    test_loss, test_accuracy = evaluate(model, test_loader)
    print("\n[EPOCH: {}], \tTest Loss: {:.4f}, \tTest Accuracy: {:.2f} % \n".format(
        epoch, test_loss, test_accuracy))
# Out:
# Train Epoch: 1 [0/60000 (0%)]	Train Loss: 2.382020
# Train Epoch: 1 [6400/60000 (11%)]	Train Loss: 2.296171
# Train Epoch: 1 [12800/60000 (21%)]	Train Loss: 2.308382
# Train Epoch: 1 [19200/60000 (32%)]	Train Loss: 2.269007
# Train Epoch: 1 [25600/60000 (43%)]	Train Loss: 2.328333
# Train Epoch: 1 [32000/60000 (53%)]	Train Loss: 2.263226
# Train Epoch: 1 [38400/60000 (64%)]	Train Loss: 2.290527
# Train Epoch: 1 [44800/60000 (75%)]	Train Loss: 2.274746
# Train Epoch: 1 [51200/60000 (85%)]	Train Loss: 2.278943
# Train Epoch: 1 [57600/60000 (96%)]	Train Loss: 2.270777
#
# [EPOCH: 1], 	Test Loss: 2.2413, 	Test Accuracy: 27.16 %
#
# Train Epoch: 2 [0/60000 (0%)]	Train Loss: 2.294581
# Train Epoch: 2 [6400/60000 (11%)]	Train Loss: 2.163991
# Train Epoch: 2 [12800/60000 (21%)]	Train Loss: 2.188200
# Train Epoch: 2 [19200/60000 (32%)]	Train Loss: 2.178425
# Train Epoch: 2 [25600/60000 (43%)]	Train Loss: 2.047373
# Train Epoch: 2 [32000/60000 (53%)]	Train Loss: 1.970008
# Train Epoch: 2 [38400/60000 (64%)]	Train Loss: 1.580423
# Train Epoch: 2 [44800/60000 (75%)]	Train Loss: 1.594899
# Train Epoch: 2 [51200/60000 (85%)]	Train Loss: 1.537675
# Train Epoch: 2 [57600/60000 (96%)]	Train Loss: 1.415447
#
# [EPOCH: 2], 	Test Loss: 1.3097, 	Test Accuracy: 64.00 %
#
# Train Epoch: 3 [0/60000 (0%)]	Train Loss: 1.364987
# Train Epoch: 3 [6400/60000 (11%)]	Train Loss: 1.251159
# Train Epoch: 3 [12800/60000 (21%)]	Train Loss: 1.307460
# Train Epoch: 3 [19200/60000 (32%)]	Train Loss: 1.076654
# Train Epoch: 3 [25600/60000 (43%)]	Train Loss: 0.878806
# Train Epoch: 3 [32000/60000 (53%)]	Train Loss: 1.052199
# Train Epoch: 3 [38400/60000 (64%)]	Train Loss: 1.015461
# Train Epoch: 3 [44800/60000 (75%)]	Train Loss: 0.902054
# Train Epoch: 3 [51200/60000 (85%)]	Train Loss: 0.734131
# Train Epoch: 3 [57600/60000 (96%)]	Train Loss: 0.756351
#
# [EPOCH: 3], 	Test Loss: 0.7703, 	Test Accuracy: 77.11 %
#
# Train Epoch: 4 [0/60000 (0%)]	Train Loss: 1.141278
# Train Epoch: 4 [6400/60000 (11%)]	Train Loss: 0.928933
# Train Epoch: 4 [12800/60000 (21%)]	Train Loss: 0.583042
# Train Epoch: 4 [19200/60000 (32%)]	Train Loss: 0.564165
# Train Epoch: 4 [25600/60000 (43%)]	Train Loss: 0.738104
# Train Epoch: 4 [32000/60000 (53%)]	Train Loss: 0.980832
# Train Epoch: 4 [38400/60000 (64%)]	Train Loss: 0.624575
# Train Epoch: 4 [44800/60000 (75%)]	Train Loss: 0.599574
# Train Epoch: 4 [51200/60000 (85%)]	Train Loss: 0.509314
# Train Epoch: 4 [57600/60000 (96%)]	Train Loss: 0.645614
#
# [EPOCH: 4], 	Test Loss: 0.5618, 	Test Accuracy: 83.57 %
#
# Train Epoch: 5 [0/60000 (0%)]	Train Loss: 0.629336
# Train Epoch: 5 [6400/60000 (11%)]	Train Loss: 0.649456
# Train Epoch: 5 [12800/60000 (21%)]	Train Loss: 0.823048
# Train Epoch: 5 [19200/60000 (32%)]	Train Loss: 0.347197
# Train Epoch: 5 [25600/60000 (43%)]	Train Loss: 0.471453
# Train Epoch: 5 [32000/60000 (53%)]	Train Loss: 0.428552
# Train Epoch: 5 [38400/60000 (64%)]	Train Loss: 0.474964
# Train Epoch: 5 [44800/60000 (75%)]	Train Loss: 0.231226
# Train Epoch: 5 [51200/60000 (85%)]	Train Loss: 0.470914
# Train Epoch: 5 [57600/60000 (96%)]	Train Loss: 0.582755
#
# [EPOCH: 5], 	Test Loss: 0.4681, 	Test Accuracy: 86.30 %
#
# Train Epoch: 6 [0/60000 (0%)]	Train Loss: 0.419598
# Train Epoch: 6 [6400/60000 (11%)]	Train Loss: 0.368092
# Train Epoch: 6 [12800/60000 (21%)]	Train Loss: 0.369254
# Train Epoch: 6 [19200/60000 (32%)]	Train Loss: 0.730147
# Train Epoch: 6 [25600/60000 (43%)]	Train Loss: 0.496472
# Train Epoch: 6 [32000/60000 (53%)]	Train Loss: 0.300340
# Train Epoch: 6 [38400/60000 (64%)]	Train Loss: 0.309980
# Train Epoch: 6 [44800/60000 (75%)]	Train Loss: 0.347196
# Train Epoch: 6 [51200/60000 (85%)]	Train Loss: 0.383271
# Train Epoch: 6 [57600/60000 (96%)]	Train Loss: 0.501898
#
# [EPOCH: 6], 	Test Loss: 0.4103, 	Test Accuracy: 88.26 %
#
# Train Epoch: 7 [0/60000 (0%)]	Train Loss: 0.631180
# Train Epoch: 7 [6400/60000 (11%)]	Train Loss: 0.257900
# Train Epoch: 7 [12800/60000 (21%)]	Train Loss: 0.627718
# Train Epoch: 7 [19200/60000 (32%)]	Train Loss: 0.397605
# Train Epoch: 7 [25600/60000 (43%)]	Train Loss: 0.490333
# Train Epoch: 7 [32000/60000 (53%)]	Train Loss: 0.499837
# Train Epoch: 7 [38400/60000 (64%)]	Train Loss: 0.807671
# Train Epoch: 7 [44800/60000 (75%)]	Train Loss: 0.478572
# Train Epoch: 7 [51200/60000 (85%)]	Train Loss: 0.334450
# Train Epoch: 7 [57600/60000 (96%)]	Train Loss: 0.206727
#
# [EPOCH: 7], 	Test Loss: 0.3797, 	Test Accuracy: 89.06 %
#
# Train Epoch: 8 [0/60000 (0%)]	Train Loss: 0.427905
# Train Epoch: 8 [6400/60000 (11%)]	Train Loss: 0.184323
# Train Epoch: 8 [12800/60000 (21%)]	Train Loss: 0.342291
# Train Epoch: 8 [19200/60000 (32%)]	Train Loss: 0.346577
# Train Epoch: 8 [25600/60000 (43%)]	Train Loss: 0.328554
# Train Epoch: 8 [32000/60000 (53%)]	Train Loss: 0.166604
# Train Epoch: 8 [38400/60000 (64%)]	Train Loss: 0.246508
# Train Epoch: 8 [44800/60000 (75%)]	Train Loss: 0.411479
# Train Epoch: 8 [51200/60000 (85%)]	Train Loss: 0.228449
# Train Epoch: 8 [57600/60000 (96%)]	Train Loss: 0.388114
#
# [EPOCH: 8], 	Test Loss: 0.3610, 	Test Accuracy: 89.51 %
#
# Train Epoch: 9 [0/60000 (0%)]	Train Loss: 0.213146
# Train Epoch: 9 [6400/60000 (11%)]	Train Loss: 0.378569
# Train Epoch: 9 [12800/60000 (21%)]	Train Loss: 0.461644
# Train Epoch: 9 [19200/60000 (32%)]	Train Loss: 0.268729
# Train Epoch: 9 [25600/60000 (43%)]	Train Loss: 0.467022
# Train Epoch: 9 [32000/60000 (53%)]	Train Loss: 0.279377
# Train Epoch: 9 [38400/60000 (64%)]	Train Loss: 0.359715
# Train Epoch: 9 [44800/60000 (75%)]	Train Loss: 0.309750
# Train Epoch: 9 [51200/60000 (85%)]	Train Loss: 0.319031
# Train Epoch: 9 [57600/60000 (96%)]	Train Loss: 0.333676
#
# [EPOCH: 9], 	Test Loss: 0.3439, 	Test Accuracy: 90.05 %
#
# Train Epoch: 10 [0/60000 (0%)]	Train Loss: 0.237795
# Train Epoch: 10 [6400/60000 (11%)]	Train Loss: 0.281554
# Train Epoch: 10 [12800/60000 (21%)]	Train Loss: 0.377930
# Train Epoch: 10 [19200/60000 (32%)]	Train Loss: 0.362787
# Train Epoch: 10 [25600/60000 (43%)]	Train Loss: 0.496419
# Train Epoch: 10 [32000/60000 (53%)]	Train Loss: 0.240186
# Train Epoch: 10 [38400/60000 (64%)]	Train Loss: 0.325332
# Train Epoch: 10 [44800/60000 (75%)]	Train Loss: 0.578941
# Train Epoch: 10 [51200/60000 (85%)]	Train Loss: 0.169367
# Train Epoch: 10 [57600/60000 (96%)]	Train Loss: 0.454502
#
# [EPOCH: 10], 	Test Loss: 0.3341, 	Test Accuracy: 90.33 %

# %% [markdown]
# ### Question 4. Please write a line-by-line explanation of the code above. (Simple MLP only)
#
#
# *   Use '#' for Python!
# *   ChatGPT allowed :) -- but please try to understand the code
# *   But you don't really have to understand everything -- we'll revisit MLP again in detail

# %% [markdown]
# ### Question 5 (Optional). Please read and summarize the following 3 documents:
#
# *    https://wikidocs.net/57168 <br>
# PyTorch 패키지에 관한 내용 <br>
# torch | 기본 수학 함수 등 <br>
# torch.autograd | 미분을 위한 패키지 <br>
# torch.nn | RNN 등 Layer, ReLU 등 Activation, MSE 등 Loss가 내장 <br>
# torch.optim | Learning rate, Momentum과 같은 Parameter들의 설정 <br>
#
# *    https://wikidocs.net/52460 <br>
# N차원 텐서 = N차원 배열과 같이 생각할 수 있다 <br>
# 2차원: (batch_size, dim) Input이 벡터인 평범한 경우 <br>
# 3차원: (batch_size, width, height) Image processing <br>
# 3차원: (batch_size, len, dim) NLP <br> <br>
# t = torch.tensor([[1.,2.,3.],[1.,2.,3.]]) 과 같이 텐서 만들기 <br>
# t.dim() == 2 (텐서의 차원) / t.size() == torch.Size([2,3]) (텐서의 Shape) <br><br>
# [Broadcast]<br>Shape 안맞는 텐서 연산 시 값들을 복사해 사이즈가 자동으로 맞춰짐<br><br>
# [matmul]<br>m1.matmul(m2)와 같은 문법으로 행렬 곱셈 수행<br><br>
# [mean]<br>m1.mean(dim=i)과 같이 하여 평균 계산. i번째 차원은 제외됨<br>
# 예를 들어 dim=0이면 행 제외하므로, 열 별로 평균이 나온다.<br>
# dim=-1이면 맨 마지막 차원을 제외한다는 뜻이다<br><br>
# [max]<br>m1.max()는 최댓값을 반환한다<br>
# m1.max(dim=i)면 또 i번째 차원 제거하고 (max, argmax)를 반환한다<br>
# 즉 리턴결과[0] == 최댓값 / 리턴결과[1] == 최댓값의 인덱스
#
# *    https://wikidocs.net/52846 <br>
# [view]<br>t.view([-1,2,3])는 Shape를 -1,2,3으로 바꾼다는 뜻<br>
# 여기서 -1은 원소 개수가 보존되도록 알아서 하라는 와일드카드<br>
# 이를 이용해 행렬을 벡터로 Flatten하는 등의 작업이 가능<br><br>
# [squeeze]<br>t.squeeze()는 shape가 1인 차원을 없애버리고 정리한다<br>
# [unsqueeze]<br>t.unsqueeze(i)는 i번째 차원의 shape=1로 차원을 삽입<br><br>
# [형변환] t.float()  // float으로 형변환<br>
# [연결] torch.cat([t1,t2], dim=i)  // i번째 차원 size가 늘어나도록 Concatenate<br>
# [쌓기] torch.stack([t1,t2])  // 차원이 늘어나도록 합친다. unsqueeze가 내장된 것<br>
# [0 Tensor] torch.ones_like(t) // t와 같은 size에 0으로 채워진 텐서<br>
# [1 Tensor] torch.zeros_like(t) // t와 같은 size에 1으로 채워진 텐서<br>
# [덮어쓰기] t.mul_(2.) // 언더바를 붙이면 C에서 a*=2와 같이 쓸 수 있음<br>

# %% [markdown]
# ### The End.

# %% [markdown]
# ##### Please upload your Colab file @Github https://github.com/duneag2/intro-dl/tree/main/Assignment1
#
# *   First, make your folder by your name (e.g. seungeun)
# *   Then upload your Jupyter Notebook file under that directory
#
# ###### Need Help?
#
#
#
# *   Please refer to this link https://yeko90.tistory.com/entry/%ED%8C%8C%EC%9D%B4%EC%8D%AC-colab%EC%BD%94%EB%9E%A9%EC%97%90%EC%84%9C-%EC%95%95%EC%B6%95%ED%8C%8C%EC%9D%BC-%ED%92%80%EA%B8%B0 OR
# *   Just save your Jupyter Notebook (.ipynb) file in here (colab) and upload via 'Add file' - 'Upload files' https://nthree.tistory.com/60
