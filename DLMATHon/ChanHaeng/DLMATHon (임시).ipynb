# %% [markdown]
# # 2024 Winter Introduction to Deep Learning
# ### Based on Prof. Oh's Youtube Lecture
# https://youtube.com/playlist?list=PLvbUC2Zh5oJvByu9KL82bswYT2IKf0K1M
#
# > DL MATH + DATATHON = DL MATHON
#
#
# *   Written by Seungeun Lee
# *   대회에서 사용되는 모든 이미지는 모델 학습을 위해서만 사용해주세요 (다른 용도로 사용 금지!)
# *   Please use all images from the competition only for model training (no other uses!)

# %% [markdown]
# ### Track 1. 한국 음식 이미지 분류
# ##### https://www.kaggle.com/competitions/2021-data-creator-camp-1120-1/data
# ##### 2021 데이터 크리에이터 캠프 (NIA 주최 데이터 분석 대회)에 출제된 문제입니다.
# ##### 학습데이터 : 3496 장 / 검증데이터 : 689 장 / 평가데이터 : 958 장으로 구성되어 있지만, 평가데이터에 대한 정답지가 없기 때문에 학습데이터 학습하고, 검증데이터로 평가하도록 하겠습니다 (평가데이터는 무시해주세요)
# ##### target은 BoiledDown (조림) / Rice (밥) / Noodle (면) / Roasted (구이) / Kimchi (김치) 총 5개로 구성되어 있습니다.
# ##### hhttps://drive.google.com/file/d/1wBJRhn7R_puujj_2LXjq-xvG03LucaFO/view?usp=drive_link

# %% [markdown]
# ### Track 1. Korean Food Image Classification
# ##### https://www.kaggle.com/competitions/2021-data-creator-camp-1120-1/data
# #####  This problem was presented at the 2021 Data Creator Camp, organized by NIA (National Information Society Agency).
# ##### The dataset consists of 3496 training images, 689 validation images, and 958 evaluation images. However, there are no ground truth labels for the evaluation data. Therefore, training will be performed on the training data, and evaluation will be carried out on the validation data (please disregard the evaluation data).
# ##### The target categories include BoiledDown, Rice, Noodle, Roasted, and Kimchi, totaling 5 classes.
# ##### https://drive.google.com/file/d/1wBJRhn7R_puujj_2LXjq-xvG03LucaFO/view?usp=drive_link

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms, datasets

# %%
if torch.cuda.is_available():
    DEVICE = torch.device('cuda')
else:
    DEVICE = torch.device('cpu')

print('Using PyTorch version:', torch.__version__, ' Device:', DEVICE)
# Out:
# Using PyTorch version: 2.3.1+cu121  Device: cuda

# %%
BATCH_SIZE = 32
EPOCHS = 10

# %%
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomResizedCrop(224),  # Randomly crop and resize to 224x224
        transforms.RandomHorizontalFlip(),  # Randomly flip horizontally
        transforms.ToTensor(),              # Convert to tensor
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])  # Normalize to ImageNet means and std
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),             # Resize the shorter side to 256
        transforms.CenterCrop(224),         # Crop the center 224x224
        transforms.ToTensor(),              # Convert to tensor
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])  # Normalize to ImageNet means and std
    ]),
}

image_datasets = {x: datasets.ImageFolder("/content/drive/MyDrive/intro-dl/kfood/", data_transforms[x]) for x in ['train', 'val']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size = BATCH_SIZE, shuffle = True) for x in ['train', 'val']}

# %%
for (X_train, y_train) in dataloaders['train']:
    print('X_train:', X_train.size(), 'type:', X_train.type())
    print('y_train:', y_train.size(), 'type:', y_train.type())
    break
# Out:
# X_train: torch.Size([32, 3, 224, 224]) type: torch.FloatTensor
# y_train: torch.Size([32]) type: torch.LongTensor

# %%
pltsize = 1
plt.figure(figsize=(10 * pltsize, pltsize))

for i in range(10):
    plt.subplot(1, 10, i + 1)
    plt.axis('off')
    plt.imshow(np.transpose(X_train[i], (1, 2, 0)))
    plt.title('Class: ' + str(y_train[i].item()))
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
import torchvision.models as models
model = models.resnet50(pretrained = True)

for parameter in model.parameters():
    parameter.requires_grad = True
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 156MB/s]

# %%
num_ftrs = model.fc.in_features
model.fc = nn.Linear(num_ftrs, 5)
model = model.to(DEVICE)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr = 0.001)

# %%
def train(model, train_loader, optimizer, log_interval):
    model.train()
    for batch_idx, (image, label) in enumerate(train_loader):
        image = image.to(DEVICE)
        label = label.to(DEVICE, dtype=torch.long)
        optimizer.zero_grad()
        output = model(image)

        loss = criterion(output, label)
        loss.backward()
        optimizer.step()

        if batch_idx % log_interval == 0:
            print("Train Epoch: {} [{}/{} ({:.0f}%)]\tTrain Loss: {:.6f}".format(
                epoch, batch_idx * len(image),
                len(train_loader.dataset), 100. * batch_idx / len(train_loader),
                loss.item()))

# %%
def evaluate(model, test_loader):
    model.eval()
    test_loss = 0
    correct = 0

    with torch.no_grad():
        for image, label in test_loader:
            image = image.to(DEVICE)
            label = label.to(DEVICE, dtype=torch.long)
            output = model(image)

            test_loss += criterion(output, label).item()
            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(label.view_as(pred)).sum().item()

    test_loss /= (len(test_loader.dataset) / BATCH_SIZE)
    test_accuracy = 100. * correct / len(test_loader.dataset)
    return test_loss, test_accuracy

# %%
for epoch in range(1, EPOCHS + 1):
    train(model, dataloaders["train"], optimizer, log_interval = 5)
    valid_loss, valid_accuracy = evaluate(model, dataloaders["val"])
    print("\n[EPOCH: {}], \tTest Loss: {:.4f}, \tTest Accuracy: {:.2f} % \n".format(
        epoch, valid_loss, valid_accuracy))
# Out:
# Train Epoch: 1 [0/5132 (0%)]	Train Loss: 1.739205
# Train Epoch: 1 [160/5132 (3%)]	Train Loss: 1.540290
# Train Epoch: 1 [320/5132 (6%)]	Train Loss: 1.024380
# Train Epoch: 1 [480/5132 (9%)]	Train Loss: 0.960705
# Train Epoch: 1 [640/5132 (12%)]	Train Loss: 0.851457
# Train Epoch: 1 [800/5132 (16%)]	Train Loss: 0.842817
# Train Epoch: 1 [960/5132 (19%)]	Train Loss: 0.915711
# Train Epoch: 1 [1120/5132 (22%)]	Train Loss: 0.923751
# Train Epoch: 1 [1280/5132 (25%)]	Train Loss: 0.901408
# Train Epoch: 1 [1440/5132 (28%)]	Train Loss: 0.914719
# Train Epoch: 1 [1600/5132 (31%)]	Train Loss: 0.845373
# Train Epoch: 1 [1760/5132 (34%)]	Train Loss: 0.937750
# Train Epoch: 1 [1920/5132 (37%)]	Train Loss: 0.810872
# Train Epoch: 1 [2080/5132 (40%)]	Train Loss: 0.812491
# Train Epoch: 1 [2240/5132 (43%)]	Train Loss: 0.937702
# Train Epoch: 1 [2400/5132 (47%)]	Train Loss: 0.823654
# Train Epoch: 1 [2560/5132 (50%)]	Train Loss: 1.051407
# Train Epoch: 1 [2720/5132 (53%)]	Train Loss: 0.836999
# Train Epoch: 1 [2880/5132 (56%)]	Train Loss: 0.775312
# Train Epoch: 1 [3040/5132 (59%)]	Train Loss: 0.703842
# Train Epoch: 1 [3200/5132 (62%)]	Train Loss: 0.978426
# Train Epoch: 1 [3360/5132 (65%)]	Train Loss: 0.948425
# Train Epoch: 1 [3520/5132 (68%)]	Train Loss: 0.895863
# Train Epoch: 1 [3680/5132 (71%)]	Train Loss: 0.834825
# Train Epoch: 1 [3840/5132 (75%)]	Train Loss: 1.006363
# Train Epoch: 1 [4000/5132 (78%)]	Train Loss: 0.949396
# Train Epoch: 1 [4160/5132 (81%)]	Train Loss: 0.686140
# Train Epoch: 1 [4320/5132 (84%)]	Train Loss: 0.840725
# Train Epoch: 1 [4480/5132 (87%)]	Train Loss: 0.657735
# Train Epoch: 1 [4640/5132 (90%)]	Train Loss: 0.838925
# Train Epoch: 1 [4800/5132 (93%)]	Train Loss: 1.172492
# Train Epoch: 1 [4960/5132 (96%)]	Train Loss: 0.909931
# Train Epoch: 1 [1920/5132 (99%)]	Train Loss: 0.978605
#
# [EPOCH: 1], 	Test Loss: 0.8545, 	Test Accuracy: 68.00 %
#
# Train Epoch: 2 [0/5132 (0%)]	Train Loss: 0.986640
# Train Epoch: 2 [160/5132 (3%)]	Train Loss: 1.001985
# Train Epoch: 2 [320/5132 (6%)]	Train Loss: 0.962569
# Train Epoch: 2 [480/5132 (9%)]	Train Loss: 0.582579
# Train Epoch: 2 [640/5132 (12%)]	Train Loss: 0.883644
# Train Epoch: 2 [800/5132 (16%)]	Train Loss: 0.945342
# Train Epoch: 2 [960/5132 (19%)]	Train Loss: 0.618168
# Train Epoch: 2 [1120/5132 (22%)]	Train Loss: 0.766583
# Train Epoch: 2 [1280/5132 (25%)]	Train Loss: 0.780279
# Train Epoch: 2 [1440/5132 (28%)]	Train Loss: 0.931238
# Train Epoch: 2 [1600/5132 (31%)]	Train Loss: 0.715527
# Train Epoch: 2 [1760/5132 (34%)]	Train Loss: 0.842524
# Train Epoch: 2 [1920/5132 (37%)]	Train Loss: 0.806149
# Train Epoch: 2 [2080/5132 (40%)]	Train Loss: 0.721641
# Train Epoch: 2 [2240/5132 (43%)]	Train Loss: 1.112826
# Train Epoch: 2 [2400/5132 (47%)]	Train Loss: 0.986352
# Train Epoch: 2 [2560/5132 (50%)]	Train Loss: 0.852980
# Train Epoch: 2 [2720/5132 (53%)]	Train Loss: 0.930069
# Train Epoch: 2 [2880/5132 (56%)]	Train Loss: 0.702948
# Train Epoch: 2 [3040/5132 (59%)]	Train Loss: 1.105818
# Train Epoch: 2 [3200/5132 (62%)]	Train Loss: 0.970875
# Train Epoch: 2 [3360/5132 (65%)]	Train Loss: 0.962801
# Train Epoch: 2 [3520/5132 (68%)]	Train Loss: 0.834691
# Train Epoch: 2 [3680/5132 (71%)]	Train Loss: 0.796784
# Train Epoch: 2 [3840/5132 (75%)]	Train Loss: 0.779991
# Train Epoch: 2 [4000/5132 (78%)]	Train Loss: 0.911750
# Train Epoch: 2 [4160/5132 (81%)]	Train Loss: 0.971125
# Train Epoch: 2 [4320/5132 (84%)]	Train Loss: 0.947928
# Train Epoch: 2 [4480/5132 (87%)]	Train Loss: 0.721580
# Train Epoch: 2 [4640/5132 (90%)]	Train Loss: 0.980560
# Train Epoch: 2 [4800/5132 (93%)]	Train Loss: 0.903675
# Train Epoch: 2 [4960/5132 (96%)]	Train Loss: 0.995093
# Train Epoch: 2 [1920/5132 (99%)]	Train Loss: 0.859597
#
# [EPOCH: 2], 	Test Loss: 0.8703, 	Test Accuracy: 68.00 %
#
# Train Epoch: 3 [0/5132 (0%)]	Train Loss: 0.752822
# Train Epoch: 3 [160/5132 (3%)]	Train Loss: 0.903308
# Train Epoch: 3 [320/5132 (6%)]	Train Loss: 0.953559
# Train Epoch: 3 [480/5132 (9%)]	Train Loss: 0.824025
# Train Epoch: 3 [640/5132 (12%)]	Train Loss: 1.144703
# Train Epoch: 3 [800/5132 (16%)]	Train Loss: 0.813684
# Train Epoch: 3 [960/5132 (19%)]	Train Loss: 0.941791
# Train Epoch: 3 [1120/5132 (22%)]	Train Loss: 0.554058
# Train Epoch: 3 [1280/5132 (25%)]	Train Loss: 1.034278
# Train Epoch: 3 [1440/5132 (28%)]	Train Loss: 0.802934
# Train Epoch: 3 [1600/5132 (31%)]	Train Loss: 0.906656
# Train Epoch: 3 [1760/5132 (34%)]	Train Loss: 0.755903
# Train Epoch: 3 [1920/5132 (37%)]	Train Loss: 0.853438
# Train Epoch: 3 [2080/5132 (40%)]	Train Loss: 1.019744
# Train Epoch: 3 [2240/5132 (43%)]	Train Loss: 1.150819
# Train Epoch: 3 [2400/5132 (47%)]	Train Loss: 0.875462
# Train Epoch: 3 [2560/5132 (50%)]	Train Loss: 0.789018
# Train Epoch: 3 [2720/5132 (53%)]	Train Loss: 0.855207
# Train Epoch: 3 [2880/5132 (56%)]	Train Loss: 0.907194
# Train Epoch: 3 [3040/5132 (59%)]	Train Loss: 0.911645
# Train Epoch: 3 [3200/5132 (62%)]	Train Loss: 0.932326
# Train Epoch: 3 [3360/5132 (65%)]	Train Loss: 0.697741
# Train Epoch: 3 [3520/5132 (68%)]	Train Loss: 0.957306
# Train Epoch: 3 [3680/5132 (71%)]	Train Loss: 1.039086
# Train Epoch: 3 [3840/5132 (75%)]	Train Loss: 0.808875
# Train Epoch: 3 [4000/5132 (78%)]	Train Loss: 0.934373
# Train Epoch: 3 [4160/5132 (81%)]	Train Loss: 0.682454
# Train Epoch: 3 [4320/5132 (84%)]	Train Loss: 0.731788
# Train Epoch: 3 [4480/5132 (87%)]	Train Loss: 0.740749
# Train Epoch: 3 [4640/5132 (90%)]	Train Loss: 0.844945
# Train Epoch: 3 [4800/5132 (93%)]	Train Loss: 0.905518
# Train Epoch: 3 [4960/5132 (96%)]	Train Loss: 0.880660
# Train Epoch: 3 [1920/5132 (99%)]	Train Loss: 0.740643
#
# [EPOCH: 3], 	Test Loss: 0.8589, 	Test Accuracy: 68.02 %
#
# Train Epoch: 4 [0/5132 (0%)]	Train Loss: 0.874861
# Train Epoch: 4 [160/5132 (3%)]	Train Loss: 0.974713
# Train Epoch: 4 [320/5132 (6%)]	Train Loss: 0.756413
# Train Epoch: 4 [480/5132 (9%)]	Train Loss: 0.653360
# Train Epoch: 4 [640/5132 (12%)]	Train Loss: 0.824575
# Train Epoch: 4 [800/5132 (16%)]	Train Loss: 0.898429
# Train Epoch: 4 [960/5132 (19%)]	Train Loss: 0.756127
# Train Epoch: 4 [1120/5132 (22%)]	Train Loss: 0.701784
# Train Epoch: 4 [1280/5132 (25%)]	Train Loss: 1.198094
# Train Epoch: 4 [1440/5132 (28%)]	Train Loss: 0.841636
# Train Epoch: 4 [1600/5132 (31%)]	Train Loss: 1.008035
# Train Epoch: 4 [1760/5132 (34%)]	Train Loss: 1.015754
# Train Epoch: 4 [1920/5132 (37%)]	Train Loss: 0.905397
# Train Epoch: 4 [2080/5132 (40%)]	Train Loss: 0.750942
# Train Epoch: 4 [2240/5132 (43%)]	Train Loss: 0.915016
# Train Epoch: 4 [2400/5132 (47%)]	Train Loss: 0.747595
# Train Epoch: 4 [2560/5132 (50%)]	Train Loss: 0.865871
# Train Epoch: 4 [2720/5132 (53%)]	Train Loss: 0.820887
# Train Epoch: 4 [2880/5132 (56%)]	Train Loss: 0.932930
# Train Epoch: 4 [3040/5132 (59%)]	Train Loss: 0.984711
# Train Epoch: 4 [3200/5132 (62%)]	Train Loss: 0.806748
# Train Epoch: 4 [3360/5132 (65%)]	Train Loss: 0.770035
# Train Epoch: 4 [3520/5132 (68%)]	Train Loss: 0.794477
# Train Epoch: 4 [3680/5132 (71%)]	Train Loss: 0.691225
# Train Epoch: 4 [3840/5132 (75%)]	Train Loss: 0.775999
# Train Epoch: 4 [4000/5132 (78%)]	Train Loss: 0.723005
# Train Epoch: 4 [4160/5132 (81%)]	Train Loss: 1.065812
# Train Epoch: 4 [4320/5132 (84%)]	Train Loss: 0.931115
# Train Epoch: 4 [4480/5132 (87%)]	Train Loss: 0.911643
# Train Epoch: 4 [4640/5132 (90%)]	Train Loss: 0.760174
# Train Epoch: 4 [4800/5132 (93%)]	Train Loss: 0.826057
# Train Epoch: 4 [4960/5132 (96%)]	Train Loss: 1.016618
# Train Epoch: 4 [1920/5132 (99%)]	Train Loss: 0.864853
#
# [EPOCH: 4], 	Test Loss: 1.0875, 	Test Accuracy: 68.00 %
#
# Train Epoch: 5 [0/5132 (0%)]	Train Loss: 1.063445
# Train Epoch: 5 [160/5132 (3%)]	Train Loss: 0.698369
# Train Epoch: 5 [320/5132 (6%)]	Train Loss: 0.812280
# Train Epoch: 5 [480/5132 (9%)]	Train Loss: 0.855590
# Train Epoch: 5 [640/5132 (12%)]	Train Loss: 0.905976
# Train Epoch: 5 [800/5132 (16%)]	Train Loss: 0.976008
# Train Epoch: 5 [960/5132 (19%)]	Train Loss: 0.660289
# Train Epoch: 5 [1120/5132 (22%)]	Train Loss: 0.952477
# Train Epoch: 5 [1280/5132 (25%)]	Train Loss: 0.926744
# Train Epoch: 5 [1440/5132 (28%)]	Train Loss: 0.876793
# Train Epoch: 5 [1600/5132 (31%)]	Train Loss: 0.894984
# Train Epoch: 5 [1760/5132 (34%)]	Train Loss: 0.889695
# Train Epoch: 5 [1920/5132 (37%)]	Train Loss: 0.697668
# Train Epoch: 5 [2080/5132 (40%)]	Train Loss: 0.879430
# Train Epoch: 5 [2240/5132 (43%)]	Train Loss: 1.048028
# Train Epoch: 5 [2400/5132 (47%)]	Train Loss: 0.864259
# Train Epoch: 5 [2560/5132 (50%)]	Train Loss: 0.736677
# Train Epoch: 5 [2720/5132 (53%)]	Train Loss: 0.921024
# Train Epoch: 5 [2880/5132 (56%)]	Train Loss: 0.926293
# Train Epoch: 5 [3040/5132 (59%)]	Train Loss: 0.780915
# Train Epoch: 5 [3200/5132 (62%)]	Train Loss: 0.677539
# Train Epoch: 5 [3360/5132 (65%)]	Train Loss: 0.842415
# Train Epoch: 5 [3520/5132 (68%)]	Train Loss: 0.595777
# Train Epoch: 5 [3680/5132 (71%)]	Train Loss: 0.798085
# Train Epoch: 5 [3840/5132 (75%)]	Train Loss: 1.030742
# Train Epoch: 5 [4000/5132 (78%)]	Train Loss: 1.153981
# Train Epoch: 5 [4160/5132 (81%)]	Train Loss: 0.942890
# Train Epoch: 5 [4320/5132 (84%)]	Train Loss: 0.925574
# Train Epoch: 5 [4480/5132 (87%)]	Train Loss: 0.834898
# Train Epoch: 5 [4640/5132 (90%)]	Train Loss: 0.944623
# Train Epoch: 5 [4800/5132 (93%)]	Train Loss: 0.700003
# Train Epoch: 5 [4960/5132 (96%)]	Train Loss: 0.845846
# Train Epoch: 5 [1920/5132 (99%)]	Train Loss: 0.868765
#
# [EPOCH: 5], 	Test Loss: 0.8505, 	Test Accuracy: 68.00 %
#
# Train Epoch: 6 [0/5132 (0%)]	Train Loss: 1.016852
# Train Epoch: 6 [160/5132 (3%)]	Train Loss: 0.897967
# Train Epoch: 6 [320/5132 (6%)]	Train Loss: 0.676523
# Train Epoch: 6 [480/5132 (9%)]	Train Loss: 0.749074
# Train Epoch: 6 [640/5132 (12%)]	Train Loss: 1.246781
# Train Epoch: 6 [800/5132 (16%)]	Train Loss: 0.729901
# Train Epoch: 6 [960/5132 (19%)]	Train Loss: 0.634297
# Train Epoch: 6 [1120/5132 (22%)]	Train Loss: 0.698298
# Train Epoch: 6 [1280/5132 (25%)]	Train Loss: 0.883800
# Train Epoch: 6 [1440/5132 (28%)]	Train Loss: 0.969744
# Train Epoch: 6 [1600/5132 (31%)]	Train Loss: 0.914600
# Train Epoch: 6 [1760/5132 (34%)]	Train Loss: 0.813515
# Train Epoch: 6 [1920/5132 (37%)]	Train Loss: 0.955947
# Train Epoch: 6 [2080/5132 (40%)]	Train Loss: 0.949003
# Train Epoch: 6 [2240/5132 (43%)]	Train Loss: 0.971887
# Train Epoch: 6 [2400/5132 (47%)]	Train Loss: 0.811762
# Train Epoch: 6 [2560/5132 (50%)]	Train Loss: 0.791428
# Train Epoch: 6 [2720/5132 (53%)]	Train Loss: 0.797273
# Train Epoch: 6 [2880/5132 (56%)]	Train Loss: 0.894089
# Train Epoch: 6 [3040/5132 (59%)]	Train Loss: 1.054902
# Train Epoch: 6 [3200/5132 (62%)]	Train Loss: 0.990017
# Train Epoch: 6 [3360/5132 (65%)]	Train Loss: 0.758956
# Train Epoch: 6 [3520/5132 (68%)]	Train Loss: 0.926319
# Train Epoch: 6 [3680/5132 (71%)]	Train Loss: 0.792134
# Train Epoch: 6 [3840/5132 (75%)]	Train Loss: 0.776888
# Train Epoch: 6 [4000/5132 (78%)]	Train Loss: 0.848663
# Train Epoch: 6 [4160/5132 (81%)]	Train Loss: 0.873221
# Train Epoch: 6 [4320/5132 (84%)]	Train Loss: 0.735741
# Train Epoch: 6 [4480/5132 (87%)]	Train Loss: 0.787058
# Train Epoch: 6 [4640/5132 (90%)]	Train Loss: 0.911108
# Train Epoch: 6 [4800/5132 (93%)]	Train Loss: 0.913489
# Train Epoch: 6 [4960/5132 (96%)]	Train Loss: 0.922764
# Train Epoch: 6 [1920/5132 (99%)]	Train Loss: 0.985732
#
# [EPOCH: 6], 	Test Loss: 0.8614, 	Test Accuracy: 68.00 %
#
# Train Epoch: 7 [0/5132 (0%)]	Train Loss: 0.791811
# Train Epoch: 7 [160/5132 (3%)]	Train Loss: 0.935554
# Train Epoch: 7 [320/5132 (6%)]	Train Loss: 0.833917
# Train Epoch: 7 [480/5132 (9%)]	Train Loss: 0.944837
# Train Epoch: 7 [640/5132 (12%)]	Train Loss: 0.969726
# Train Epoch: 7 [800/5132 (16%)]	Train Loss: 0.924256
# Train Epoch: 7 [960/5132 (19%)]	Train Loss: 0.727022
# Train Epoch: 7 [1120/5132 (22%)]	Train Loss: 0.887160
# Train Epoch: 7 [1280/5132 (25%)]	Train Loss: 0.760410
# Train Epoch: 7 [1440/5132 (28%)]	Train Loss: 0.864044
# Train Epoch: 7 [1600/5132 (31%)]	Train Loss: 0.717625
# Train Epoch: 7 [1760/5132 (34%)]	Train Loss: 0.575776
# Train Epoch: 7 [1920/5132 (37%)]	Train Loss: 0.581152
# Train Epoch: 7 [2080/5132 (40%)]	Train Loss: 0.855857
# Train Epoch: 7 [2240/5132 (43%)]	Train Loss: 0.821900
# Train Epoch: 7 [2400/5132 (47%)]	Train Loss: 0.842833
# Train Epoch: 7 [2560/5132 (50%)]	Train Loss: 1.072759
# Train Epoch: 7 [2720/5132 (53%)]	Train Loss: 0.877033
# Train Epoch: 7 [2880/5132 (56%)]	Train Loss: 0.659115
# Train Epoch: 7 [3040/5132 (59%)]	Train Loss: 1.058504
# Train Epoch: 7 [3200/5132 (62%)]	Train Loss: 0.957210
# Train Epoch: 7 [3360/5132 (65%)]	Train Loss: 1.025462
# Train Epoch: 7 [3520/5132 (68%)]	Train Loss: 0.894670
# Train Epoch: 7 [3680/5132 (71%)]	Train Loss: 1.068422
# Train Epoch: 7 [3840/5132 (75%)]	Train Loss: 0.828467
# Train Epoch: 7 [4000/5132 (78%)]	Train Loss: 0.810332
# Train Epoch: 7 [4160/5132 (81%)]	Train Loss: 0.888526
# Train Epoch: 7 [4320/5132 (84%)]	Train Loss: 0.736517
# Train Epoch: 7 [4480/5132 (87%)]	Train Loss: 0.797379
# Train Epoch: 7 [4640/5132 (90%)]	Train Loss: 0.750312
# Train Epoch: 7 [4800/5132 (93%)]	Train Loss: 0.786762
# Train Epoch: 7 [4960/5132 (96%)]	Train Loss: 0.777895
# Train Epoch: 7 [1920/5132 (99%)]	Train Loss: 0.814590
#
# [EPOCH: 7], 	Test Loss: 0.8526, 	Test Accuracy: 68.00 %
#
# Train Epoch: 8 [0/5132 (0%)]	Train Loss: 0.856196
# Train Epoch: 8 [160/5132 (3%)]	Train Loss: 0.924875
# Train Epoch: 8 [320/5132 (6%)]	Train Loss: 0.920863
# Train Epoch: 8 [480/5132 (9%)]	Train Loss: 0.560838
# Train Epoch: 8 [640/5132 (12%)]	Train Loss: 0.739059
# Train Epoch: 8 [800/5132 (16%)]	Train Loss: 0.756186
# Train Epoch: 8 [960/5132 (19%)]	Train Loss: 0.999872
# Train Epoch: 8 [1120/5132 (22%)]	Train Loss: 0.750497
# Train Epoch: 8 [1280/5132 (25%)]	Train Loss: 0.601842
# Train Epoch: 8 [1440/5132 (28%)]	Train Loss: 0.887352
# Train Epoch: 8 [1600/5132 (31%)]	Train Loss: 0.878617
# Train Epoch: 8 [1760/5132 (34%)]	Train Loss: 0.912050
# Train Epoch: 8 [1920/5132 (37%)]	Train Loss: 1.040284
# Train Epoch: 8 [2080/5132 (40%)]	Train Loss: 0.922416
# Train Epoch: 8 [2240/5132 (43%)]	Train Loss: 0.979485
# Train Epoch: 8 [2400/5132 (47%)]	Train Loss: 0.706895
# Train Epoch: 8 [2560/5132 (50%)]	Train Loss: 0.703892
# Train Epoch: 8 [2720/5132 (53%)]	Train Loss: 0.853641
# Train Epoch: 8 [2880/5132 (56%)]	Train Loss: 0.787759
# Train Epoch: 8 [3040/5132 (59%)]	Train Loss: 0.799335
# Train Epoch: 8 [3200/5132 (62%)]	Train Loss: 0.868938
# Train Epoch: 8 [3360/5132 (65%)]	Train Loss: 0.687917
# Train Epoch: 8 [3520/5132 (68%)]	Train Loss: 1.103166
# Train Epoch: 8 [3680/5132 (71%)]	Train Loss: 0.885731
# Train Epoch: 8 [3840/5132 (75%)]	Train Loss: 0.952999
# Train Epoch: 8 [4000/5132 (78%)]	Train Loss: 0.907491
# Train Epoch: 8 [4160/5132 (81%)]	Train Loss: 0.781156
# Train Epoch: 8 [4320/5132 (84%)]	Train Loss: 0.775034
# Train Epoch: 8 [4480/5132 (87%)]	Train Loss: 0.841907
# Train Epoch: 8 [4640/5132 (90%)]	Train Loss: 0.884905
# Train Epoch: 8 [4800/5132 (93%)]	Train Loss: 1.014475
# Train Epoch: 8 [4960/5132 (96%)]	Train Loss: 0.822151
# Train Epoch: 8 [1920/5132 (99%)]	Train Loss: 0.711191
#
# [EPOCH: 8], 	Test Loss: 0.8550, 	Test Accuracy: 68.00 %
#
# Train Epoch: 9 [0/5132 (0%)]	Train Loss: 1.034829
# Train Epoch: 9 [160/5132 (3%)]	Train Loss: 0.871537
# Train Epoch: 9 [320/5132 (6%)]	Train Loss: 0.737194
# Train Epoch: 9 [480/5132 (9%)]	Train Loss: 0.890309
# Train Epoch: 9 [640/5132 (12%)]	Train Loss: 0.815082
# Train Epoch: 9 [800/5132 (16%)]	Train Loss: 0.756682
# Train Epoch: 9 [960/5132 (19%)]	Train Loss: 0.773757
# Train Epoch: 9 [1120/5132 (22%)]	Train Loss: 0.836161
# Train Epoch: 9 [1280/5132 (25%)]	Train Loss: 0.765379
# Train Epoch: 9 [1440/5132 (28%)]	Train Loss: 0.856058
# Train Epoch: 9 [1600/5132 (31%)]	Train Loss: 0.665814
# Train Epoch: 9 [1760/5132 (34%)]	Train Loss: 0.855954
# Train Epoch: 9 [1920/5132 (37%)]	Train Loss: 0.928892
# Train Epoch: 9 [2080/5132 (40%)]	Train Loss: 0.773248
# Train Epoch: 9 [2240/5132 (43%)]	Train Loss: 0.834804
# Train Epoch: 9 [2400/5132 (47%)]	Train Loss: 0.881733
# Train Epoch: 9 [2560/5132 (50%)]	Train Loss: 0.647775
# Train Epoch: 9 [2720/5132 (53%)]	Train Loss: 0.943406
# Train Epoch: 9 [2880/5132 (56%)]	Train Loss: 0.838623
# Train Epoch: 9 [3040/5132 (59%)]	Train Loss: 0.750928
# Train Epoch: 9 [3200/5132 (62%)]	Train Loss: 0.703882
# Train Epoch: 9 [3360/5132 (65%)]	Train Loss: 0.874454
# Train Epoch: 9 [3520/5132 (68%)]	Train Loss: 0.804663
# Train Epoch: 9 [3680/5132 (71%)]	Train Loss: 0.879728
# Train Epoch: 9 [3840/5132 (75%)]	Train Loss: 0.942054
# Train Epoch: 9 [4000/5132 (78%)]	Train Loss: 0.752424
# Train Epoch: 9 [4160/5132 (81%)]	Train Loss: 0.783366
# Train Epoch: 9 [4320/5132 (84%)]	Train Loss: 0.970680
# Train Epoch: 9 [4480/5132 (87%)]	Train Loss: 0.686919
# Train Epoch: 9 [4640/5132 (90%)]	Train Loss: 0.906697
# Train Epoch: 9 [4800/5132 (93%)]	Train Loss: 1.041219
# Train Epoch: 9 [4960/5132 (96%)]	Train Loss: 0.827481
# Train Epoch: 9 [1920/5132 (99%)]	Train Loss: 0.799477
#
# [EPOCH: 9], 	Test Loss: 0.8488, 	Test Accuracy: 68.00 %
#
# Train Epoch: 10 [0/5132 (0%)]	Train Loss: 0.878566
# Train Epoch: 10 [160/5132 (3%)]	Train Loss: 0.785330
# Train Epoch: 10 [320/5132 (6%)]	Train Loss: 1.049393
# Train Epoch: 10 [480/5132 (9%)]	Train Loss: 0.944153
# Train Epoch: 10 [640/5132 (12%)]	Train Loss: 0.713703
# Train Epoch: 10 [800/5132 (16%)]	Train Loss: 0.798765
# Train Epoch: 10 [960/5132 (19%)]	Train Loss: 0.819457
# Train Epoch: 10 [1120/5132 (22%)]	Train Loss: 0.823945
# Train Epoch: 10 [1280/5132 (25%)]	Train Loss: 0.877718
# Train Epoch: 10 [1440/5132 (28%)]	Train Loss: 0.843331
# Train Epoch: 10 [1600/5132 (31%)]	Train Loss: 1.086125
# Train Epoch: 10 [1760/5132 (34%)]	Train Loss: 0.895404
# Train Epoch: 10 [1920/5132 (37%)]	Train Loss: 0.977441
# Train Epoch: 10 [2080/5132 (40%)]	Train Loss: 0.833055
# Train Epoch: 10 [2240/5132 (43%)]	Train Loss: 0.763758
# Train Epoch: 10 [2400/5132 (47%)]	Train Loss: 0.821426
# Train Epoch: 10 [2560/5132 (50%)]	Train Loss: 0.719930
# Train Epoch: 10 [2720/5132 (53%)]	Train Loss: 0.818986
# Train Epoch: 10 [2880/5132 (56%)]	Train Loss: 0.887919
# Train Epoch: 10 [3040/5132 (59%)]	Train Loss: 0.796392
# Train Epoch: 10 [3200/5132 (62%)]	Train Loss: 0.935112
# Train Epoch: 10 [3360/5132 (65%)]	Train Loss: 0.835999
# Train Epoch: 10 [3520/5132 (68%)]	Train Loss: 0.859797
# Train Epoch: 10 [3680/5132 (71%)]	Train Loss: 0.867277
# Train Epoch: 10 [3840/5132 (75%)]	Train Loss: 0.742274
# Train Epoch: 10 [4000/5132 (78%)]	Train Loss: 0.795653
# Train Epoch: 10 [4160/5132 (81%)]	Train Loss: 0.712770
# Train Epoch: 10 [4320/5132 (84%)]	Train Loss: 0.822683
# Train Epoch: 10 [4480/5132 (87%)]	Train Loss: 0.806802
# Train Epoch: 10 [4640/5132 (90%)]	Train Loss: 1.081842
# Train Epoch: 10 [4800/5132 (93%)]	Train Loss: 0.735160
# Train Epoch: 10 [4960/5132 (96%)]	Train Loss: 0.930860
# Train Epoch: 10 [1920/5132 (99%)]	Train Loss: 0.630597
#
# [EPOCH: 10], 	Test Loss: 0.8470, 	Test Accuracy: 68.00 %

# %% [markdown]
# ### Track 2. Turtle Classification
# ##### Suinne's pet turtle, 'Ddubuki' vs not_ddubuki
# ##### In data science, especially in academic projects, a significant amount of time is dedicated not only to implementing and developing models but also to the crucial task of data preprocessing. This is due to the varied formats of data (jpg, heic, png, tiff, etc.) and the potential differences in colormaps.
# ##### Additionally, real-world data is often limited in quantity, and there is a significant imbalance in the distribution of targets, making classification challenging.
# ##### Through Track 2, we aim to explore methods to address these practical challenges. Please start with preprocessing the data, unifying it into a single file format, considering the various extensions. It is recommended to use libraries such as 'os', that you have learned previously.
# ##### The dataset consists of 98 training images and 21 evaluation images.
# ##### The target classes are ddubuk and not_ddubuk.
# ##### https://drive.google.com/file/d/1pHQMKPBvY1kju82i64fCB-yVyEtnWybh/view?usp=drive_link

# %% [markdown]
# ### The End.

# %% [markdown]
# ##### Please upload your Colab file @Github https://github.com/duneag2/intro-dl/tree/main/DLMATHon
#
# *   First, make your folder by your name (e.g. seungeun)
# *   Then upload your "Jupyter Notebook" file under that directory
#
# *   결과물을 업로드한 후에 저 (승은)에게 개인톡으로 알려주시면 leaderboard에 결과를 반영하겠습니다
# *   평가데이터를 학습데이터에 사용하는 행위 등 cheating과 FastAI와 같은 shortcut 사용은 안 돼요~!!
#
# *   After uploading your results, please inform me (Seungeun) through personal chat, and I will reflect the results on the leaderboard
# *   Cheating, such as using evaluation data for training, and shortcuts like FastAI, are not allowed. Thank you for your understanding!
